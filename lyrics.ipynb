# %%
import pandas as pd

df = pd.read_csv('song_lyrics.csv')

df
# Out:
#                      title      tag                    artist  year   views  \
# 0                Killa Cam      rap                   Cam'ron  2004  173166
# 1               Can I Live      rap                     JAY-Z  1996  468624
# 2        Forgive Me Father      rap                  Fabolous  2003    4743
# 3             Down and Out      rap                   Cam'ron  2004  144404
# 4                   Fly In      rap                 Lil Wayne  2005   78271
# ...                    ...      ...                       ...   ...     ...
# 5134851              Ocean      pop                   Effemar  2022       3
# 5134852            64 Bars      rap                    Rapido  2022       4
# 5134853    Raise Our Hands      pop  Culture Code, Pag & Mylo  2016       3
# 5134854                CEO      rap               Antropolita  2022       5
# 5134855         New Number  country         Alana Springsteen  2022       1
#
#                                              features  \
# ...

# %%
df.query("artist == 'Lil Ugly Mane'")
# Out:
#                                 title   tag         artist  year  views  \
# 60593         RADIATIONLUNG POLLUTION   rap  Lil Ugly Mane  2011  25332
# 60596      Tell Dem Boyz Ima Skeleton   rap  Lil Ugly Mane  2011   4188
# 70757                  THROW DEM GUNZ   rap  Lil Ugly Mane  2012  64707
# 72071                     BREEZEM OUT   rap  Lil Ugly Mane  2012  15271
# 72203                      SLICK RICK   rap  Lil Ugly Mane  2012  30018
# ...                               ...   ...            ...   ...    ...
# 4805320                ‌keep me going  rock  Lil Ugly Mane  2010     56
# 4848264                        Addict   rap  Lil Ugly Mane  2021     81
# 4868896  Interlude to Oblivion Access  misc  Lil Ugly Mane  2021      8
# 4897994                    Lights Out   rap  Lil Ugly Mane  2015     15
# 4976805              IPHONE FREESTYLE   rap  Lil Ugly Mane  2022     23
#
#                     features  \
# 60593    {"Supa SortaHuman"}
# 60596                     {}
# ...

# %%
# print(
#     df.query("artist == 'Death Grips'").iloc[6].loc['lyrics']
# )

# lyrics = df.query("artist.isin(['The Garden', 'George Clanton', 'Death Grips', 'King Krule', 'Lil Ugly Mane']) ")['lyrics'].to_list()
lyrics = df.query("tag == 'rap'").head(5000)['lyrics'].to_list()

# %%
len(lyrics)
# Out:
# 1966

# %%
with open("lyrics.txt", "w") as f:
    f.write("\n".join(lyrics))
